# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51751/RL_Lab/blob/main/RL_Lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

machines = ['A', 'B', 'C']
N = {'A': 0, 'B': 0, 'C': 0}
R = {'A': [], 'B': [], 'C': []}
Q = {'A': 0, 'B': 0, 'C': 0}

epsilon = 0.2

for i in range(10):
    r = random.random()

    if r < epsilon:
        m = random.choice(machines)
        print("Exploration")
    else:
        m = max(Q, key=Q.get)
        print("Exploitation")

    print("Play with machine", m)
    reward = float(input("Enter reward: "))

    N[m] += 1
    R[m].append(reward)

    Q[m] = Q[m] + (reward - Q[m]) / N[m]

print("\nN Table:", N)
print("R Table:", R)
print("Q Table:", Q)5
# Out:
# Exploitation
# Play with machine A
# Enter reward: 3
# Exploitation
# Play with machine A
# Enter reward: 4
# Exploitation
# Play with machine A
# Enter reward: 2
# Exploitation
# Play with machine A
# Enter reward: 5
# Exploitation
# Play with machine A
# Enter reward: 6
# Exploitation
# Play with machine A
# Enter reward: 7
# Exploitation
# Play with machine A
# Enter reward: 5
# Exploitation
# Play with machine A
# Enter reward: 8
# Exploitation
# Play with machine A
# Enter reward: 4
# Exploitation
# Play with machine A
# Enter reward: 3
#
# N Table: {'A': 10, 'B': 0, 'C': 0}
# R Table: {'A': [3.0, 4.0, 2.0, 5.0, 6.0, 7.0, 5.0, 8.0, 4.0, 3.0], 'B': [], 'C': []}
# Q Table: {'A': 4.7, 'B': 0, 'C': 0}
