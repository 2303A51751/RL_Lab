# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51751/RL_Lab/blob/main/RL_lab5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install gymnasium

# %%
import gymnasium as gym


def random_agent(env_name):

    # Create environment
    if env_name == "CartPole":
        env = gym.make("CartPole-v1")

    elif env_name == "MountainCar":
        env = gym.make("MountainCar-v0")

    elif env_name == "FrozenLake":
        env = gym.make("FrozenLake-v1", is_slippery=True)

    else:
        print("Invalid environment")
        return

    # Reset environment
    state, info = env.reset()

    total_reward = 0
    steps = 0

    print("\nEnvironment:", env_name)
    print("Initial State:", state)
    print("Action Space:", env.action_space)

    while True:

        # Select random action
        action = env.action_space.sample()

        # Execute action
        next_state, reward, terminated, truncated, info = env.step(action)

        print(
            "Step:", steps + 1,
            "Action:", action,
            "Reward:", reward,
            "Next State:", next_state
        )

        total_reward += reward
        steps += 1

        state = next_state

        if terminated or truncated:
            break

    # Calculate average reward
    average_reward = total_reward / steps

    print("\nEpisode Completed")
    print("Total Steps:", steps)
    print("Total Reward:", total_reward)
    print("Average Reward:", round(average_reward, 4))

    env.close()


# -------------------------------------------------
# MAIN
# -------------------------------------------------

print("RANDOM AGENT - REINFORCEMENT LEARNING")

print("\n1. CartPole")
print("2. MountainCar")
print("3. FrozenLake")

choice = input("\nEnter choice: ")

if choice == "1":
    random_agent("CartPole")

elif choice == "2":
    random_agent("MountainCar")

elif choice == "3":
    random_agent("FrozenLake")

else:
    print("Invalid choice")
# Out:
# RANDOM AGENT - REINFORCEMENT LEARNING
#
# 1. CartPole
# 2. MountainCar
# 3. FrozenLake
#
# Enter choice: 1
#
# Environment: CartPole
# Initial State: [ 0.03893963  0.0193231  -0.00490044  0.00821759]
# Action Space: Discrete(2)
# Step: 1 Action: 0 Reward: 1.0 Next State: [ 0.03932609 -0.17572823 -0.00473609  0.29935035]
# Step: 2 Action: 0 Reward: 1.0 Next State: [ 0.03581153 -0.37078235  0.00125092  0.5905358 ]
# Step: 3 Action: 0 Reward: 1.0 Next State: [ 0.02839588 -0.5659218   0.01306163  0.8836126 ]
# Step: 4 Action: 0 Reward: 1.0 Next State: [ 0.01707745 -0.76121867  0.03073388  1.1803728 ]
# Step: 5 Action: 0 Reward: 1.0 Next State: [ 0.00185307 -0.95672584  0.05434134  1.4825295 ]
# Step: 6 Action: 1 Reward: 1.0 Next State: [-0.01728144 -0.76230717  0.08399193  1.2073004 ]
# Step: 7 Action: 0 Reward: 1.0 Next State: [-0.03252758 -0.95840776  0.10813794  1.525079  ]
# Step: 8 Action: 0 Reward: 1.0 Next State: [-0.05169574 -1.1546563   0.13863952  1.849463  ]
# ...

# %%
import gymnasium as gym


def random_agent(env_name):

    # Create environment
    if env_name == "CartPole":
        env = gym.make("CartPole-v1")

    elif env_name == "MountainCar":
        env = gym.make("MountainCar-v0")

    elif env_name == "FrozenLake":
        env = gym.make("FrozenLake-v1", is_slippery=True)

    else:
        print("Invalid environment")
        return

    # Reset environment
    state, info = env.reset()

    total_reward = 0
    steps = 0

    print("\nEnvironment:", env_name)
    print("Initial State:", state)
    print("Action Space:", env.action_space)

    while True:

        # Select random action
        action = env.action_space.sample()

        # Execute action
        next_state, reward, terminated, truncated, info = env.step(action)

        print(
            "Step:", steps + 1,
            "Action:", action,
            "Reward:", reward,
            "Next State:", next_state
        )

        total_reward += reward
        steps += 1

        state = next_state

        if terminated or truncated:
            break

    # Calculate average reward
    average_reward = total_reward / steps

    print("\nEpisode Completed")
    print("Total Steps:", steps)
    print("Total Reward:", total_reward)
    print("Average Reward:", round(average_reward, 4))

    env.close()


# -------------------------------------------------
# MAIN
# -------------------------------------------------

print("RANDOM AGENT - REINFORCEMENT LEARNING")

print("\n1. CartPole")
print("2. MountainCar")
print("3. FrozenLake")

choice = input("\nEnter choice: ")

if choice == "1":
    random_agent("CartPole")

elif choice == "2":
    random_agent("MountainCar")

elif choice == "3":
    random_agent("FrozenLake")

else:
    print("Invalid choice")
# Out:
# RANDOM AGENT - REINFORCEMENT LEARNING
#
# 1. CartPole
# 2. MountainCar
# 3. FrozenLake
#
# Enter choice: 2
#
# Environment: MountainCar
# Initial State: [-0.40721276  0.        ]
# Action Space: Discrete(3)
# Step: 1 Action: 1 Reward: -1.0 Next State: [-0.40806803 -0.00085527]
# Step: 2 Action: 1 Reward: -1.0 Next State: [-0.40977255 -0.0017045 ]
# Step: 3 Action: 1 Reward: -1.0 Next State: [-0.41231424 -0.00254171]
# Step: 4 Action: 1 Reward: -1.0 Next State: [-0.41567516 -0.00336092]
# Step: 5 Action: 0 Reward: -1.0 Next State: [-0.42083144 -0.00515628]
# Step: 6 Action: 1 Reward: -1.0 Next State: [-0.42674634 -0.00591488]
# Step: 7 Action: 2 Reward: -1.0 Next State: [-0.43237743 -0.0056311 ]
# Step: 8 Action: 2 Reward: -1.0 Next State: [-0.43768418 -0.00530675]
# Step: 9 Action: 0 Reward: -1.0 Next State: [-0.44462818 -0.006944  ]
# Step: 10 Action: 1 Reward: -1.0 Next State: [-0.45215893 -0.00753075]
# Step: 11 Action: 2 Reward: -1.0 Next State: [-0.4592214  -0.00706246]
# ...

# %%
import gymnasium as gym


def random_agent(env_name):

    # Create environment
    if env_name == "CartPole":
        env = gym.make("CartPole-v1")

    elif env_name == "MountainCar":
        env = gym.make("MountainCar-v0")

    elif env_name == "FrozenLake":
        env = gym.make("FrozenLake-v1", is_slippery=True)

    else:
        print("Invalid environment")
        return

    # Reset environment
    state, info = env.reset()

    total_reward = 0
    steps = 0

    print("\nEnvironment:", env_name)
    print("Initial State:", state)
    print("Action Space:", env.action_space)

    while True:

        # Select random action
        action = env.action_space.sample()

        # Execute action
        next_state, reward, terminated, truncated, info = env.step(action)

        print(
            "Step:", steps + 1,
            "Action:", action,
            "Reward:", reward,
            "Next State:", next_state
        )

        total_reward += reward
        steps += 1

        state = next_state

        if terminated or truncated:
            break

    # Calculate average reward
    average_reward = total_reward / steps

    print("\nEpisode Completed")
    print("Total Steps:", steps)
    print("Total Reward:", total_reward)
    print("Average Reward:", round(average_reward, 4))

    env.close()


# -------------------------------------------------
# MAIN
# -------------------------------------------------

print("RANDOM AGENT - REINFORCEMENT LEARNING")

print("\n1. CartPole")
print("2. MountainCar")
print("3. FrozenLake")

choice = input("\nEnter choice: ")

if choice == "1":
    random_agent("CartPole")

elif choice == "2":
    random_agent("MountainCar")

elif choice == "3":
    random_agent("FrozenLake")

else:
    print("Invalid choice")
# Out:
# RANDOM AGENT - REINFORCEMENT LEARNING
#
# 1. CartPole
# 2. MountainCar
# 3. FrozenLake
#
# Enter choice: 3
#
# Environment: FrozenLake
# Initial State: 0
# Action Space: Discrete(4)
# Step: 1 Action: 0 Reward: 0 Next State: 0
# Step: 2 Action: 0 Reward: 0 Next State: 0
# Step: 3 Action: 2 Reward: 0 Next State: 4
# Step: 4 Action: 3 Reward: 0 Next State: 5
#
# Episode Completed
# Total Steps: 4
# Total Reward: 0
# Average Reward: 0.0
